# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.DataFrame({'x':[0,1,2,3],'y':[4,7,7,8]})
df.head()
# Out:
#    x  y
# 0  0  4
# 1  1  7
# 2  2  7
# 3  3  8

# %%
#plotting with the df
plt.plot(df.x,df.y,color='green', marker='*',linestyle='dashed',linewidth=2, markersize=12,label='line 1')
#plt.plot(df.y,df.x,color='green', marker='*',linestyle='dashed',linewidth=2, markersize=12,label='line 1')
plt.xlabel('Values of x')
plt.ylabel('Values of y')
# Out:
# Text(0, 0.5, 'Values of y')

# %%
plt.scatter(df.x,df.y, s = 5, c = 'r')
plt.show()

# %%
import seaborn as sns; sns.set(style="ticks", color_codes=True)
iris = df
g = sns.pairplot(iris, kind="reg")

# %%
import seaborn as sns
# %matplotlib inline
sns.pairplot(data=df,x_vars=df.x,y_vars=df.y,height=7, aspect=0.7,kind='reg')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-ebd4a5dab9ae> in <module>
#       1 import seaborn as sns
# ...

# %%
sns.jointplot(x=df.x,y=df.y,data=df,kind='reg')
